# %% [markdown]
# # Model training

# %%
import torch
import random
import numpy as np

from ultralytics import YOLO

# %% [markdown]
# ## Set Seed

# %%
random_seed = 42

torch.manual_seed(random_seed)
random.seed(random_seed)
np.random.seed(random_seed)

# %% [markdown]
# ## GPU

# %%
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# True
# NVIDIA GeForce RTX 3070

# %% [markdown]
# ## Model

# %%
model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 2.7MB/s 2.3s.3s<0.1s2.0s

# %%
results = model.train(
    data="../data/processed/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,

    project="../runs",
    name="traffic_sign_v1",

    exist_ok=True
)
# Out:
# Ultralytics 8.4.45  Python-3.8.5 torch-2.4.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070, 8191MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/processed/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=traffic_sign_v1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=F:\Software\Dataspell\TrafficSignDetection\runs\runs\traffic_sign_v1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 2.6MB/s 2.1s.0s<0.0s1.6s
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 1866.3857.1 MB/s, size: 359.7 KB)
# train: Scanning F:\Software\Dataspell\TrafficSignDetection\data\processed\labels\train... 500 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 500/500 2.1Kit/s 0.2s0.0ss
# train: New cache created: F:\Software\Dataspell\TrafficSignDetection\data\processed\labels\train.cache
# val: Fast image access  (ping: 0.10.1 ms, read: 942.41025.8 MB/s, size: 467.8 KB)
# val: Scanning F:\Software\Dataspell\TrafficSignDetection\data\processed\labels\val... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 1.8Kit/s 0.1s
# val: F:\Software\Dataspell\TrafficSignDetection\data\processed\images\val\00340.jpg: 1 duplicate labels removed
# val: New cache created: F:\Software\Dataspell\TrafficSignDetection\data\processed\labels\val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to F:\Software\Dataspell\TrafficSignDetection\runs\runs\traffic_sign_v1\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to F:\Software\Dataspell\TrafficSignDetection\runs\runs\traffic_sign_v1
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.05G       1.32      3.201     0.9216         14        640: 100% ━━━━━━━━━━━━ 32/32 1.2it/s 25.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.8it/s 1.0s0.2s
#                    all        150        251    0.00313      0.562    0.00343    0.00164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.05G      1.218      1.823      0.881         14        640: 100% ━━━━━━━━━━━━ 32/32 9.1it/s 3.5s<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.3it/s 0.6s0.2s
#                    all        150        251    0.00467      0.837     0.0114    0.00646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.05G      1.181      1.529     0.8816          9        640: 100% ━━━━━━━━━━━━ 32/32 10.5it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s0.2s
#                    all        150        251     0.0543      0.112     0.0231     0.0161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.05G      1.168      1.308     0.8686         16        640: 100% ━━━━━━━━━━━━ 32/32 10.5it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.6it/s 0.6s0.2s
#                    all        150        251    0.00437      0.179    0.00211    0.00148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.05G      1.111      1.165     0.8645         12        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.2it/s 0.5s0.2s
#                    all        150        251      0.827      0.558      0.697      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.06G      1.089       1.05     0.8525         18        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.2it/s 0.5s0.2s
#                    all        150        251      0.901      0.845      0.913      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.06G       1.11       1.01     0.8607         18        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s0.2s
#                    all        150        251      0.947      0.777      0.893      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.06G     0.9939     0.8572     0.8536         10        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.0it/s 0.6s0.2s
#                    all        150        251      0.927      0.845       0.93      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.06G      1.035     0.8148       0.85         14        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.8it/s 0.6s0.2s
#                    all        150        251      0.959      0.825      0.931      0.683
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.06G     0.9876      0.767     0.8401         15        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.2it/s 0.5s0.1s
#                    all        150        251      0.928       0.82      0.915      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.06G     0.9676     0.7313     0.8443          4        640: 100% ━━━━━━━━━━━━ 32/32 10.9it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.5it/s 0.5s0.1s
#                    all        150        251       0.91       0.89      0.935      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      2.06G      0.928     0.6897     0.8345         12        640: 100% ━━━━━━━━━━━━ 32/32 10.9it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.5it/s 0.6s0.2s
#                    all        150        251      0.925      0.861      0.924      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.06G      1.014     0.7022     0.8434         12        640: 100% ━━━━━━━━━━━━ 32/32 10.9it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.0it/s 0.7s0.2s
#                    all        150        251       0.91      0.873      0.899       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.06G     0.9262     0.6474     0.8338         13        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s0.1s
#                    all        150        251      0.949      0.812      0.908      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.06G     0.9424      0.641     0.8256          9        640: 100% ━━━━━━━━━━━━ 32/32 11.3it/s 2.8s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.5it/s 0.5s.2s
#                    all        150        251      0.898      0.896      0.904      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      2.06G     0.8978     0.6027     0.8319          5        640: 100% ━━━━━━━━━━━━ 32/32 9.8it/s 3.3s0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.9it/s 0.6s0.2s
#                    all        150        251       0.93      0.873      0.933      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      2.06G      0.945     0.6121     0.8377         12        640: 100% ━━━━━━━━━━━━ 32/32 10.2it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.4it/s 0.6s0.2s
#                    all        150        251       0.93      0.893      0.954       0.74
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      2.06G     0.8371     0.5622     0.8249         11        640: 100% ━━━━━━━━━━━━ 32/32 10.9it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.7it/s 0.5s0.1s
#                    all        150        251      0.935      0.884      0.952      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      2.06G     0.8854     0.5774     0.8185         16        640: 100% ━━━━━━━━━━━━ 32/32 11.0it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.4it/s 0.6s0.1s
#                    all        150        251       0.96      0.869      0.947      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      2.06G     0.8754     0.5581     0.8371         11        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.9it/s 0.5s0.1s
#                    all        150        251      0.904      0.863      0.892       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      2.06G     0.8543     0.5602     0.8184          5        640: 100% ━━━━━━━━━━━━ 32/32 10.6it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s0.1s
#                    all        150        251       0.86      0.865      0.838      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      2.06G     0.8407      0.555     0.8207          8        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.6it/s 0.5s0.1s
#                    all        150        251      0.945      0.883      0.939      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      2.06G     0.8606     0.5575     0.8145         10        640: 100% ━━━━━━━━━━━━ 32/32 10.0it/s 3.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.5it/s 0.5s0.1s
#                    all        150        251      0.969      0.853      0.948      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      2.06G     0.8679     0.5598     0.8189         17        640: 100% ━━━━━━━━━━━━ 32/32 10.9it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.7it/s 0.5s0.1s
#                    all        150        251      0.964      0.862      0.945      0.753
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      2.06G     0.8185     0.5111     0.8153          4        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.5it/s 0.5s0.1s
#                    all        150        251      0.928      0.884      0.934      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      2.06G     0.7983     0.5051     0.8224          7        640: 100% ━━━━━━━━━━━━ 32/32 10.9it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.8it/s 0.6s0.2s
#                    all        150        251      0.935       0.91      0.946      0.732
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      2.06G     0.8254     0.5202     0.8142          9        640: 100% ━━━━━━━━━━━━ 32/32 10.4it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.6it/s 0.5s0.1s
#                    all        150        251       0.97      0.901      0.954      0.755
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      2.06G     0.8127     0.5132     0.8001         17        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.1it/s 0.5s0.2s
#                    all        150        251      0.933      0.885      0.911      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      2.06G     0.7962     0.4992      0.812          9        640: 100% ━━━━━━━━━━━━ 32/32 10.0it/s 3.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.1it/s 0.5s0.2s
#                    all        150        251      0.936      0.879      0.931      0.732
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      2.06G     0.7788     0.4902     0.8093         11        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.7it/s 0.5s0.1s
#                    all        150        251      0.914      0.904      0.938      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      2.06G     0.7887     0.4871     0.8088          8        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.2it/s 0.6s0.2s
#                    all        150        251      0.923      0.906      0.928      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      2.06G     0.7831     0.4905     0.8107         10        640: 100% ━━━━━━━━━━━━ 32/32 10.7it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s0.1s
#                    all        150        251       0.95      0.896      0.957      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      2.06G      0.775     0.4751     0.8081         10        640: 100% ━━━━━━━━━━━━ 32/32 10.9it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.6it/s 0.5s0.1s
#                    all        150        251      0.947        0.9      0.953      0.753
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      2.06G     0.7618     0.4644     0.8056         13        640: 100% ━━━━━━━━━━━━ 32/32 10.8it/s 3.0s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.4it/s 0.5s0.1s
#                    all        150        251       0.95      0.907      0.951      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      2.06G      0.746     0.4552     0.8057         19        640: 100% ━━━━━━━━━━━━ 32/32 10.2it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.1it/s 0.6s0.1s
#                    all        150        251      0.953      0.904      0.955      0.748
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      2.06G     0.7468     0.4484     0.8099         20        640: 100% ━━━━━━━━━━━━ 32/32 6.8it/s 4.7s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s.1s
#                    all        150        251      0.924      0.916       0.94      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      2.06G     0.7254      0.441      0.804         13        640: 100% ━━━━━━━━━━━━ 32/32 10.3it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.2it/s 0.5s0.2s
#                    all        150        251      0.939      0.924      0.951      0.762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      2.06G     0.7232     0.4453     0.7986          7        640: 100% ━━━━━━━━━━━━ 32/32 9.5it/s 3.4s0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.1it/s 0.7s0.2s
#                    all        150        251      0.937      0.936      0.962      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      2.06G     0.7242     0.4471     0.8052         11        640: 100% ━━━━━━━━━━━━ 32/32 11.0it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.0it/s 0.5s.1s
#                    all        150        251      0.943      0.916      0.956      0.766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      2.06G      0.726     0.4295     0.8017          5        640: 100% ━━━━━━━━━━━━ 32/32 11.0it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.1it/s 0.5s.1s
#                    all        150        251       0.95      0.909      0.957      0.759
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      2.22G     0.6937     0.4185     0.7965          5        640: 100% ━━━━━━━━━━━━ 32/32 1.2it/s 25.9s0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.6it/s 1.4s0.2ss
#                    all        150        251      0.959      0.873      0.943      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      2.22G     0.6695     0.4177     0.8032          6        640: 100% ━━━━━━━━━━━━ 32/32 10.4it/s 3.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.4it/s 0.6s0.1s
#                    all        150        251      0.953      0.886      0.937      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      2.22G     0.6439     0.3991     0.8013          7        640: 100% ━━━━━━━━━━━━ 32/32 11.0it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 8.5it/s 0.6s0.1s
#                    all        150        251      0.956      0.884      0.954      0.757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      2.22G     0.6548     0.3893     0.7933          4        640: 100% ━━━━━━━━━━━━ 32/32 11.0it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.7it/s 0.5s0.1s
#                    all        150        251      0.946        0.9      0.945      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      2.22G     0.6541     0.3986     0.7936          7        640: 100% ━━━━━━━━━━━━ 32/32 11.1it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.1it/s 0.5s0.1s
#                    all        150        251       0.96        0.9       0.94      0.748
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      2.22G      0.639     0.3887     0.7929          6        640: 100% ━━━━━━━━━━━━ 32/32 11.0it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.6it/s 0.5s0.1s
#                    all        150        251      0.932      0.912      0.938      0.751
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      2.22G      0.626     0.3865     0.8091          6        640: 100% ━━━━━━━━━━━━ 32/32 11.0it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.7it/s 0.5s0.1s
#                    all        150        251      0.908       0.92      0.931      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      2.22G     0.6205     0.3782     0.7975          7        640: 100% ━━━━━━━━━━━━ 32/32 11.0it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.5it/s 0.5s0.1s
#                    all        150        251      0.918      0.924      0.938      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.22G     0.6052     0.3692     0.7951          7        640: 100% ━━━━━━━━━━━━ 32/32 10.9it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.7it/s 0.5s0.1s
#                    all        150        251      0.898      0.928      0.933      0.743
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.22G     0.5991     0.3586     0.7915          4        640: 100% ━━━━━━━━━━━━ 32/32 11.0it/s 2.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.7it/s 0.5s0.1s
#                    all        150        251      0.903      0.924      0.945      0.765
#
# 50 epochs completed in 0.112 hours.
# Optimizer stripped from F:\Software\Dataspell\TrafficSignDetection\runs\runs\traffic_sign_v1\weights\last.pt, 6.2MB
# Optimizer stripped from F:\Software\Dataspell\TrafficSignDetection\runs\runs\traffic_sign_v1\weights\best.pt, 6.2MB
#
# Validating F:\Software\Dataspell\TrafficSignDetection\runs\runs\traffic_sign_v1\weights\best.pt...
# Ultralytics 8.4.45  Python-3.8.5 torch-2.4.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070, 8191MiB)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.4it/s 2.1s0.4ss
#                    all        150        251      0.943      0.916      0.957      0.767
# Speed: 1.5ms preprocess, 4.0ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to F:\Software\Dataspell\TrafficSignDetection\runs\runs\traffic_sign_v1

# %%
metrics = model.val(
    data="../data/processed/data.yaml",
    split="test"
)
# Out:
# Ultralytics 8.4.45  Python-3.8.5 torch-2.4.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070, 8191MiB)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 71.337.0 MB/s, size: 383.8 KB)
# val: Scanning F:\Software\Dataspell\TrafficSignDetection\data\processed\labels\test... 91 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 91/91 172.3it/s 0.5s.5s
# val: New cache created: F:\Software\Dataspell\TrafficSignDetection\data\processed\labels\test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.1s/it 24.4s0.3ss
#                    all         91        164      0.958      0.965      0.964      0.799
# Speed: 3.3ms preprocess, 58.7ms inference, 0.0ms loss, 2.8ms postprocess per image
# Results saved to F:\Software\Dataspell\TrafficSignDetection\runs\detect\val
